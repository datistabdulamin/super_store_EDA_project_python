# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("Superstore_USA.xlsx")

# %%
df.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# ...

# %%
# checking mission values:

# %%
df.isnull().sum()
# Out:
# Row ID                   0
# Order Priority           0
# Discount                 0
# Unit Price               0
# Shipping Cost            0
# Customer ID              0
# Customer Name            0
# Ship Mode                0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Container        0
# Product Name             0
# Product Base Margin     72
# Region                   0
# State or Province        0
# City                     0
# Postal Code              0
# Order Date               0
# Ship Date                0
# Profit                   0
# Quantity ordered new     0
# Sales                    0
# Order ID                 0
# dtype: int64

# %%
# in, [Product Base Margin] the [72] values is missing.

# %%
# fill the missing values with the mean of the Coloum.

# %%
df["Product Base Margin"].fillna(df["Product Base Margin"].mean() ,inplace=True)

# %%
df.isnull().sum()
# Out:
# Row ID                  0
# Order Priority          0
# Discount                0
# Unit Price              0
# Shipping Cost           0
# Customer ID             0
# Customer Name           0
# Ship Mode               0
# Customer Segment        0
# Product Category        0
# Product Sub-Category    0
# Product Container       0
# Product Name            0
# Product Base Margin     0
# Region                  0
# State or Province       0
# City                    0
# Postal Code             0
# Order Date              0
# Ship Date               0
# Profit                  0
# Quantity ordered new    0
# Sales                   0
# Order ID                0
# dtype: int64

# %%
df.shape
# Out:
# (9426, 24)

# %% [markdown]
# # Order Priority

# %%
df["Order Priority"].unique()
# Out:
# array(['Not Specified', 'High', 'Medium', 'Low', 'Critical'], dtype=object)

# %%
df["Order Priority"].value_counts()
# Out:
# Order Priority
# High             1970
# Low              1926
# Not Specified    1881
# Medium           1844
# Critical         1805
# Name: count, dtype: int64

# %%
# make graph on Oder Priority:

# %%
plt.figure(figsize=(5,4))
sns.countplot(x="Order Priority",data=df)
plt.title("Count of Order Priority")
plt.savefig("Count of Order Priority.jpg")
plt.show()

# %% [markdown]
# # Ship Mode

# %%
df["Ship Mode"].unique()
# Out:
# array(['Regular Air', 'Express Air', 'Delivery Truck'], dtype=object)

# %%
df["Ship Mode"].value_counts()
# Out:
# Ship Mode
# Regular Air       7036
# Delivery Truck    1283
# Express Air       1107
# Name: count, dtype: int64

# %%
# make pie chart for shipping Mode:
name = df["Ship Mode"].value_counts().index
value = df["Ship Mode"].value_counts().values

# %%
plt.figure(figsize=(4,5))
plt.pie(value,labels=name,startangle=60,autopct="%0.2f%%")
plt.legend(loc=2)
plt.show()

# %%
plt.figure(figsize=(5,4))
sns.countplot(x="Ship Mode",data=df, hue="Product Category")
plt.show()

# %% [markdown]
# # Customer Segment

# %%
df["Customer Segment"].unique()
# Out:
# array(['Corporate', 'Home Office', 'Small Business', 'Consumer'],
#       dtype=object)

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Customer Segment",data=df)
plt.show()

# %% [markdown]
# # Product Category

# %%
df["Product Category"].unique()
# Out:
# array(['Office Supplies', 'Technology', 'Furniture'], dtype=object)

# %%
plt.figure(figsize=(5,4))
sns.countplot(x="Product Category", data=df)
plt.show()

# %% [markdown]
# # Product Sub-Category

# %%
# checking office supply data only:

# %%
plt.figure(figsize=(15,5))
sns.countplot(x="Product Category", hue="Product Sub-Category", data=df[df["Product Category"]=="Office Supplies"])
plt.show()

# %%
# checking Technology data:

# %%
plt.figure(figsize=(12,5))
sns.countplot(x="Product Category", hue="Product Sub-Category",data=df[df["Product Category"]=="Technology"])
plt.show()

# %%
# graph of furniture

# %%
plt.figure(figsize=(8,4))
sns.countplot(x="Product Category", hue="Product Sub-Category",data=df[df["Product Category"]=="Furniture"])
plt.show()

# %% [markdown]
# # order by year

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9426 entries, 0 to 9425
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                9426 non-null   int64
#  1   Order Priority        9426 non-null   object
#  2   Discount              9426 non-null   float64
#  3   Unit Price            9426 non-null   float64
#  4   Shipping Cost         9426 non-null   float64
#  5   Customer ID           9426 non-null   int64
#  6   Customer Name         9426 non-null   object
#  7   Ship Mode             9426 non-null   object
#  8   Customer Segment      9426 non-null   object
#  9   Product Category      9426 non-null   object
#  10  Product Sub-Category  9426 non-null   object
#  11  Product Container     9426 non-null   object
#  12  Product Name          9426 non-null   object
#  13  Product Base Margin   9426 non-null   float64
#  14  Region                9426 non-null   object
# ...

# %%
# make new coloum of Year:

# %%
df["Order Year"] = df["Order Date"].dt.year

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9426 entries, 0 to 9425
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                9426 non-null   int64
#  1   Order Priority        9426 non-null   object
#  2   Discount              9426 non-null   float64
#  3   Unit Price            9426 non-null   float64
#  4   Shipping Cost         9426 non-null   float64
#  5   Customer ID           9426 non-null   int64
#  6   Customer Name         9426 non-null   object
#  7   Ship Mode             9426 non-null   object
#  8   Customer Segment      9426 non-null   object
#  9   Product Category      9426 non-null   object
#  10  Product Sub-Category  9426 non-null   object
#  11  Product Container     9426 non-null   object
#  12  Product Name          9426 non-null   object
#  13  Product Base Margin   9426 non-null   float64
#  14  Region                9426 non-null   object
# ...

# %%
# now checking sale by year:

# %%
df["Order Year"].value_counts()
# Out:
# Order Year
# 2013    3054
# 2012    2241
# 2011    2179
# 2010    1952
# Name: count, dtype: int64

# %%
# make the graph on Order by year:

# %%
plt.figure(figsize=(5,4))
sns.countplot(x="Order Year",data=df)
plt.show()

# %% [markdown]
# # Profit Category:

# %%
df.head(2)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
#
#   State or Province       City Postal Code  Order Date  Ship Date Profit  \
# 0          Illinois    Addison       60101  2012-05-28 2012-05-30   1.32
# 1        Washington  Anacortes       98221  2010-07-07 2010-07-08   4.56
#
#   Quantity ordered new  Sales Order ID Order Year
# 0                    2   5.90    88525       2012
# 1                    4  13.01    88522       2010
#
# [2 rows x 25 columns]

# %%
df["Profit"]
# Out:
# 0          1.320000
# 1          4.560000
# 2        -47.640000
# 3        -30.510000
# 4        998.202300
#            ...
# 9421     137.860000
# 9422     -39.070000
# 9423   -1225.029097
# 9424     349.485000
# 9425      78.062400
# Name: Profit, Length: 9426, dtype: float64

# %%
# make the barplot for profit:

# %%
plt.figure(figsize=(6,4))
sns.barplot(x="Product Category",y="Profit",data=df,estimator="sum")
plt.show()

# %%
# find profit by city:

# %%
df["State or Province"].value_counts()[:5]
# Out:
# State or Province
# California    1021
# Texas          646
# Illinois       584
# New York       574
# Florida        522
# Name: count, dtype: int64

# %%
# Product Base Margin in Product Category graph:

# %%
plt.figure(figsize=(6,4))
sns.barplot(x="Product Category",y="Product Base Margin",data=df,estimator="sum")
plt.show()

# %%
#the_end;
